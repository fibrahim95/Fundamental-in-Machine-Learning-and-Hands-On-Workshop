# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 24.4 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qbkFCtvXV7pRr9acK2o5")
project = rf.workspace("guitar-qexna").project("guitar_detection-cnyil")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to guitar_detection-3 in yolov11:: 100%|██████████| 314/314 [00:00<00:00, 8332.09it/s]

# %%
# !yolo detect train data=/content/guitar_detection-3/data.yaml model=yolov8s.pt epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train3/weights/best.pt")  # build a new model from YAML


# Train the model
results = model("/content/guitar_detection-3/test/images/0019_png.rf.a6d33927ca923f07d5ff9860bebeb1c1.jpg", save=True)
# Out:
# image 1/1 /content/guitar_detection-3/test/images/0019_png.rf.a6d33927ca923f07d5ff9860bebeb1c1.jpg: 640x640 1 dot, 4 fingers, 21 frets, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
